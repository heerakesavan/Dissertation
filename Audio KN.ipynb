# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\heera\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\heera\anaconda3\lib\site-packages (from librosa) (20.4)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\heera\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: numba>=0.43.0 in c:\users\heera\anaconda3\lib\site-packages (from librosa) (0.51.2)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\heera\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\heera\anaconda3\lib\site-packages (from librosa) (4.4.2)
# Requirement already satisfied: audioread>=2.0.0 in c:\users\heera\anaconda3\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\heera\anaconda3\lib\site-packages (from librosa) (0.23.2)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\heera\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\heera\anaconda3\lib\site-packages (from librosa) (1.19.2)
# Requirement already satisfied: pooch>=1.0 in c:\users\heera\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\heera\anaconda3\lib\site-packages (from librosa) (0.17.0)
# Requirement already satisfied: six in c:\users\heera\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\heera\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\heera\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in c:\users\heera\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (50.3.1.post20201107)
# Requirement already satisfied: cffi>=1.0 in c:\users\heera\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\heera\anaconda3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: appdirs in c:\users\heera\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests in c:\users\heera\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.24.0)
# Requirement already satisfied: pycparser in c:\users\heera\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\heera\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\heera\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\heera\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\heera\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (3.0.4)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename='C:/Users/heera/OneDrive - Heerak/Desktop/UrbanSound8K/dog_bark.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is F01D-1899
#
#  Directory of C:\Users\heera\OneDrive - Heerak\Desktop\Dissertation
#
# 11-11-2021  17:03    <DIR>          .
# 11-11-2021  17:03    <DIR>          ..
# 11-11-2021  16:25    <DIR>          .ipynb_checkpoints
# 10-11-2021  10:58           314,580 Audio classification - Heera.ipynb
# 11-11-2021  17:03            17,748 Audio KN.ipynb
# 12-10-2021  13:25         5,629,536 Cross wavelet assisted CNN.pdf
# 21-10-2021  17:03                 0 Dissertation.txt
# 12-10-2021  12:50         1,939,514 Localization and clustering.pdf
# 12-10-2021  13:29         1,468,505 Neurofuzzy inference system.pdf
# 12-10-2021  12:42         2,994,369 Peterson graph method paper.pdf
# 19-10-2021  22:42    <DIR>          traindata
#                7 File(s)     12,364,252 bytes
#                4 Dir(s)  240,383,602,688 bytes free

# %%
### Dog Sound
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
